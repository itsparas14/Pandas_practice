# %%
import pandas as pd
print("pandas verssion:", pd.__version__)
# Out:
# pandas verssion: 2.3.3

# %%
# SERRIES: single column in a spreadsheet with indices(labels)
fruits= pd.Series(['apple','banana','peach'])
print(fruits)
# Out:
# 0     apple
# 1    banana
# 2     peach
# dtype: object

# %%
# dataFrame: full spreadhsheet with rows and columns
# dictionary: {} anyting inside this parenthesis is a DICT
# list: [] these are the list.

import pandas as pd
Data= {
    "Name":["Paras","Ronaldo"],
    'profession':['analyst','Footballer']
}
df = pd.DataFrame(Data)
print(df)
# Out:
#       Name  profession
# 0    Paras     analyst
# 1  Ronaldo  Footballer
